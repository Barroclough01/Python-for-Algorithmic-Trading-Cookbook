# %% [markdown]
# ## Streaming Real Time Options Data with ThetaData

# %%
# %pip install thetadata

# %%
import datetime as dt
from thetadata import ThetaClient, OptionRight, StreamMsgType, StreamResponseType

# %%
def callback(msg):
    # Handle received messages
    if msg.type == StreamMsgType.TRADE:
        print("----------------------------------------------------")
        print(f"Contract: {msg.contract.to_string()}")
        print(f"Trade: {msg.trade.to_string()}")
        print(f"Last quote at time of trade: {msg.quote.to_string()}")

# %%
def stream_all_trades():
    # Initialize the ThetaClient with your credentials
    client = ThetaClient(username="default", passwd="default")

    # Connect to the data stream
    client.connect_stream(callback)

    # Request full trade stream for options
    req_id = client.req_full_trade_stream_opt()

    # Verify subscription
    if client.verify(req_id) != StreamResponseType.SUBSCRIBED:
        raise Exception("Unable to stream.")

# %% [markdown]
# Start streaming all trades

# %%
stream_all_trades()
# Out:
# If you require API support, feel free to join our discord server! http://discord.thetadata.us
# ------------------------------------------------------------------------------------------------
# You are using the free version of Theta Data. You are currently limited to 20 requests / minute.
# A data subscription can be purchased at https://thetadata.net. If you already have a ThetaData
# subscription, specify the username and passwd parameters.
# ------------------------------------------------------------------------------------------------
# [03-02-2025 13:09:30] INFO: Starting Theta Terminal v1.8.4 Revision A...
# [03-02-2025 13:09:30] INFO: Using C:\Users\paxto\ThetaData\ThetaTerminal\logs as the log directory
# [03-02-2025 13:09:30] INFO: Using C:\Users\paxto\ThetaData\ThetaTerminal\config_0.properties as the config file
# [03-02-2025 13:09:31] INFO: [MDDS] Attempting login as default
# [03-02-2025 13:09:31] INFO: [MDDS] CONNECTED: [nj-a.thetadata.us:12000], Bundle: STOCK.FREE, OPTION.FREE, INDEX.FREE
# [03-02-2025 13:09:31] INFO: [FPSS] Attempting login as default
# [03-02-2025 13:09:31] INFO: [FPSS] CONNECTED: [nj-a.thetadata.us:20000], Bundle: STOCK.FREE, OPTION.FREE, INDEX.FREE
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 stream_all_trades()
#
# Cell In[7], line 13, in stream_all_trades()
#      11 # Verify subscription
#      12 if client.verify(req_id) != StreamResponseType.SUBSCRIBED:
# ---> 13     raise Exception("Unable to stream.")
#
# Exception: Unable to stream.

# %% [markdown]
# Define parameters for a specific option contract

# %%
ticker = "SPY"
expiration_date = dt.date(2024, 12, 22)
strike = 474

# %%
def stream_contract():
    # Initialize the ThetaClient with your credentials
    client = ThetaClient(username="default", passwd="default")

    # Connect to the data stream
    client.connect_stream(callback)

    # Request trade stream for a specific option contract
    req_id = client.req_trade_stream_opt(
        ticker, expiration_date, strike, OptionRight.CALL
    )

    # Verify subscription
    if client.verify(req_id) != StreamResponseType.SUBSCRIBED:
        raise Exception("Unable to stream.")

# %% [markdown]
# Start streaming trades for a specific contract

# %%
stream_contract()
# Out:
# If you require API support, feel free to join our discord server! http://discord.thetadata.us
# ------------------------------------------------------------------------------------------------
# You are using the free version of Theta Data. You are currently limited to 20 requests / minute.
# A data subscription can be purchased at https://thetadata.net. If you already have a ThetaData
# subscription, specify the username and passwd parameters.
# ------------------------------------------------------------------------------------------------
# [03-02-2025 13:11:52] INFO: Starting Theta Terminal v1.8.4 Revision A...
# [03-02-2025 13:11:52] INFO: Using C:\Users\paxto\ThetaData\ThetaTerminal\logs as the log directory
# [03-02-2025 13:11:52] INFO: Using C:\Users\paxto\ThetaData\ThetaTerminal\config_0.properties as the config file
# [03-02-2025 13:11:53] INFO: [MDDS] Attempting login as default
# [03-02-2025 13:11:53] INFO: [MDDS] CONNECTED: [nj-a.thetadata.us:12000], Bundle: STOCK.FREE, OPTION.FREE, INDEX.FREE
# [03-02-2025 13:11:53] INFO: [FPSS] Attempting login as default
# [03-02-2025 13:11:53] INFO: [FPSS] CONNECTED: [nj-a.thetadata.us:20000], Bundle: STOCK.FREE, OPTION.FREE, INDEX.FREE
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 stream_contract()
#
# Cell In[10], line 15, in stream_contract()
#      13 # Verify subscription
#      14 if client.verify(req_id) != StreamResponseType.SUBSCRIBED:
# ---> 15     raise Exception("Unable to stream.")
#
# Exception: Unable to stream.

# %% [markdown]
# **Jason Strimpel** is the founder of <a href='https://pyquantnews.com/'>PyQuant News</a> and co-founder of <a href='https://www.tradeblotter.io/'>Trade Blotter</a>. His career in algorithmic trading spans 20+ years. He previously traded for a Chicago-based hedge fund, was a risk manager at JPMorgan, and managed production risk technology for an energy derivatives trading firm in London. In Singapore, he served as APAC CIO for an agricultural trading firm and built the data science team for a global metals trading firm. Jason holds degrees in Finance and Economics and a Master's in Quantitative Finance from the Illinois Institute of Technology. His career spans America, Europe, and Asia. He shares his expertise through the <a href='https://pyquantnews.com/subscribe-to-the-pyquant-newsletter/'>PyQuant Newsletter</a>, social media, and has taught over 1,000+ algorithmic trading with Python in his popular course **<a href='https://gettingstartedwithpythonforquantfinance.com/'>Getting Started With Python for Quant Finance</a>**. All code is for educational purposes only. Nothing provided here is financial advise. Use at your own risk.
